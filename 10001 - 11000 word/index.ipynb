# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

import pandas as pd
import json

# %% [markdown]
# # Code chính

# %% [markdown]
# # Tiếp tục cào khởi tạo từ index cho cần

# %%
# Đường dẫn tới file JSON
json_file_path = 'vocab_frequency_new.json'
output_json_file_path = '10000word.json'

# Định nghĩa các danh mục từ loại
categories_mapping = {
    "Danh từ": "category1: 'Danh từ'",
    "Động từ": "category2: 'Động từ'",
    "Tính từ": "category3: 'Tính từ'",
    "Số từ": "category4: 'Số từ'",
    "Lượng từ": "category5: 'Lượng từ'",
    "Phó từ": "category6: 'Phó từ'",
    "Đại từ": "category7: 'Đại từ'",
    "": "category8: 'Null'"
}

# Khởi tạo WebDriver (giả sử bạn đang dùng Chrome), nếu như cần chạy hiện rõ trình duyệt thì chạy code ở dưới
browser = webdriver.Chrome()

# URL của trang web
url = "http://tratu.soha.vn/dict/vn_vn/"
browser.get(url)

# Đọc dữ liệu từ file JSON
with open(json_file_path, 'r', encoding='utf-8') as file:
    vocab_data = json.load(file)

# Tìm vị trí bắt đầu tìm kiếm (ví dụ từ vị trí 33)
start_index = 10041

# Khởi tạo danh sách kết quả
results = []

# Thực hiện tìm kiếm từ từ vị trí start_index đến hết danh sách
for index in range(start_index, 11948):
    word = vocab_data[str(index)]
    
    # Lấy lại các phần tử input và button trước mỗi lần tìm kiếm
    input_search = browser.find_element(By.ID, 'search')
    search_button = browser.find_element(By.ID, 'btnSearch')
    
    # Clear the input field
    input_search.clear()
    
    # Send the input to the webpage
    input_search.send_keys(word)
    sleep(1)
    search_button.click()
    
    # Scrap the data
    elements = browser.find_elements(By.XPATH, "//h3/span[@class='mw-headline']")
    
    # Lấy text của tất cả các phần tử và in ra
    word_categories = []
    for element in elements:
        text = element.text.strip()
        if text in categories_mapping:
            word_categories.append(categories_mapping[text])
    
    # Tạo đối tượng kết quả và thêm vào danh sách
    result = {
        "title": word,
        "categories": word_categories
    }
    results.append(result)
    
    # Mở file JSON để thêm mới kết quả
    with open(output_json_file_path, 'a', encoding='utf-8') as outfile:
        json.dump(result, outfile, ensure_ascii=False, indent=4)
        outfile.write(",\n")  # Thêm dấu phẩy và xuống dòng để đảm bảo JSON đúng định dạng
    
    print(f"Results for '{word}': {word_categories}")
    print('-' * 20)
    
    # Đợi một chút trước khi thực hiện tìm kiếm từ tiếp theo (tùy chọn)
    sleep(2)

# Đóng trình duyệt
browser.quit()

print(f"Final results have been saved to {output_json_file_path}")
# Out:
# Results for 'liên bộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bất hảo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khắc ghi': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngư cụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mái chèo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đưa tang': ["category2: 'Động từ'"]
# --------------------
# Results for 'thảo quả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngoài lề': []
# --------------------
# Results for 'bội nhiễm': ["category2: 'Động từ'"]
# --------------------
# Results for 'động lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chuyên trị': ["category2: 'Động từ'"]
# --------------------
# Results for 'giao hoà': ["category2: 'Động từ'"]
# --------------------
# Results for 'độ lượng': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'miễn nhiễm': ["category2: 'Động từ'"]
# --------------------
# Results for 'lễ phục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'muối tiêu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh luyện': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'chim cút': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chút đỉnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biểu bì': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bao tay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thử lửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'lờ đờ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sửa chữa': ["category2: 'Động từ'"]
# --------------------
# Results for 'cắm đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhiệt lượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bức điện': []
# --------------------
# Results for 'cá mòi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tại ngũ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'toại nguyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'giải vây': ["category2: 'Động từ'"]
# --------------------
# Results for 'cá tôm': []
# --------------------
# Results for 'kim tuyến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'váy ren': []
# --------------------
# Results for 'tỉnh ngộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'khiên cưỡng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'siêu bền': []
# --------------------
# Results for 'nhân tr': []
# --------------------
# Results for 'quân phiệt': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'kêu la': ["category2: 'Động từ'"]
# --------------------
# Results for 'hát ru': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngào ngạt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lâm trận': ["category2: 'Động từ'"]
# --------------------
# Results for 'ủ rũ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bấu víu': ["category2: 'Động từ'"]
# --------------------
# Results for 'đánh liều': ["category2: 'Động từ'"]
# --------------------
# Results for 'cáu kỉnh': []
# --------------------
# Results for 'lục giác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngập chìm': ["category2: 'Động từ'"]
# --------------------
# Results for 'chắc tay': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ng tượng': []
# --------------------
# Results for 'cùng với': []
# --------------------
# Results for 'tếu táo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rã rời': ["category2: 'Động từ'"]
# --------------------
# Results for 'giao du': ["category2: 'Động từ'"]
# --------------------
# Results for 'trường đoạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bát quái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hợp lực': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'vịt trời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mạng nhện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà ống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hết hồn': ["category2: 'Động từ'"]
# --------------------
# Results for 'tối mịt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khoe mẽ': ["category2: 'Động từ'"]
# --------------------
# Results for 'vàng trắng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hầu hạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cả thảy': ["category7: 'Đại từ'"]
# --------------------
# Results for 'cây cọ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sư cô': []
# --------------------
# Results for 'nổi đoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'mới đó': []
# --------------------
# Results for 'cô chiêu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nữ tướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thể hiệ': []
# --------------------
# Results for 'trị an': []
# --------------------
# Results for 'trái vụ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khối phố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bồ kết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ghép nối': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiếp vận': ["category2: 'Động từ'"]
# --------------------
# Results for 'tơi bời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vinh hạnh': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'cao bồi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thứ phát': ["category2: 'Động từ'"]
# --------------------
# Results for 'súng ống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quý phi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thơm ngát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sách nhiễu': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà giam': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giáp hạt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân chuồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quân sư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chất rắn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nguyệt thực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'teo tóp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quấy phá': ["category2: 'Động từ'"]
# --------------------
# Results for 'hạn dùng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuốc tẩy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiếu phụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xung khắc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đấu võ': ["category2: 'Động từ'"]
# --------------------
# Results for 'võ sinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'huyết học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cường tráng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tồn vong': ["category2: 'Động từ'"]
# --------------------
# Results for 'phụ hoạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'buột miệng': ["category2: 'Động từ'"]
# --------------------
# Results for 'lay lắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mưu sát': ["category2: 'Động từ'"]
# --------------------
# Results for 'anh linh': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'bói toán': ["category2: 'Động từ'"]
# --------------------
# Results for 'hàng mã': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kè kè': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao tăng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dẫu sao': []
# --------------------
# Results for 'hoả tiễn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bánh đúc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bầu bạn': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'tha hương': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'chó sói': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngồi bệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'biệt hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ăn tiêu': ["category2: 'Động từ'"]
# --------------------
# Results for 'ẩn dật': ["category2: 'Động từ'"]
# --------------------
# Results for 'quan toà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá chiên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chầu văn': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'tránh mặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'rồng rắn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bao gói': ["category2: 'Động từ'"]
# --------------------
# Results for 'hẳn nhiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đon đả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chỉnh tề': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chính giới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đặc ân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rầu rĩ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'la cà': ["category2: 'Động từ'"]
# --------------------
# Results for 'oai hùng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đồ hàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quá tay': []
# --------------------
# Results for 'luyến láy': []
# --------------------
# Results for 'đom đóm': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'hoạt cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giáo chủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ăn đứt': ["category2: 'Động từ'"]
# --------------------
# Results for 'cau có': []
# --------------------
# Results for 'dơ bẩn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dẫn xuất': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'lưỡi câu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kỳ lân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sinh linh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khí phách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bồi bàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đối chọi': ["category2: 'Động từ'"]
# --------------------
# Results for 'ồn ã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quân thù': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng tâm': ["category3: 'Tính từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'đinh hương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuyên cần': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đại náo': ["category2: 'Động từ'"]
# --------------------
# Results for 'căm thù': ["category2: 'Động từ'"]
# --------------------
# Results for 'chủ thầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhè nhẹ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bế giảng': ["category2: 'Động từ'"]
# --------------------
# Results for 'đặc trách': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiển hách': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lưu manh': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tượng hình': ["category2: 'Động từ'"]
# --------------------
# Results for 'thêm thắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'chói lọi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thấp kém': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hao tổn': ["category2: 'Động từ'"]
# --------------------
# Results for 'non bộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sử liệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vợ cả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bưu phẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhàn hạ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kháng nguyên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'oán hận': ["category2: 'Động từ'"]
# --------------------
# Results for 'nặng tay': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khôn xiết': []
# --------------------
# Results for 'ẩn khuất': []
# --------------------
# Results for 'hồn hậu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dây thép': ["category1: 'Danh từ'"]
# --------------------
# Results for 'người dưng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cả thể': []
# --------------------
# Results for 'viễn thám': ["category2: 'Động từ'"]
# --------------------
# Results for 'ban phát': ["category2: 'Động từ'"]
# --------------------
# Results for 'mảnh khảnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cứa cổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cận chiến': []
# --------------------
# Results for 'bô lão': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bê bết': ["category3: 'Tính từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'hổ phách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nước độc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bâng khuâng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gia giảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'khinh bỉ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiêu cự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'há hốc': ["category2: 'Động từ'"]
# --------------------
# Results for 'hú vía': ["category2: 'Động từ'"]
# --------------------
# Results for 'cải biên': ["category2: 'Động từ'"]
# --------------------
# Results for 'chính danh': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'hí hửng': []
# --------------------
# Results for 'sấp mặt': []
# --------------------
# Results for 'tối kỵ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'củ đậu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mạnh bạo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thù ghét': ["category2: 'Động từ'"]
# --------------------
# Results for 'cùi chỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'li bì': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nở nang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chiến hào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ảo ảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'băng huyết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nham thạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đặc tả': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'xâu chuỗi': ["category2: 'Động từ'"]
# --------------------
# Results for 'định lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thấm th': []
# --------------------
# Results for 'vun vút': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'sùng bái': ["category2: 'Động từ'"]
# --------------------
# Results for 'khoa trương': ["category2: 'Động từ'"]
# --------------------
# Results for 'rượu mạnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh đòn': ["category2: 'Động từ'"]
# --------------------
# Results for 'gốc từ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quốc khánh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bá tước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hầm mỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'danh thiếp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồi mồi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thanh danh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vượt tuyến': ["category2: 'Động từ'"]
# --------------------
# Results for 'nửa đời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đơn ca': ["category2: 'Động từ'"]
# --------------------
# Results for 'kết duyên': ["category2: 'Động từ'"]
# --------------------
# Results for 'tú bà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hạ áp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hải đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cấm cản': ["category2: 'Động từ'"]
# --------------------
# Results for 'châm ngôn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vạn thọ': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'soi xét': ["category2: 'Động từ'"]
# --------------------
# Results for 'cặn bã': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh tinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bất luận': []
# --------------------
# Results for 'truy kích': ["category2: 'Động từ'"]
# --------------------
# Results for 'phân hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'váy xoè': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phụ phí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khoáng đạt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vũ kịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tờ mờ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoàn công': ["category2: 'Động từ'"]
# --------------------
# Results for 'thanh cao': ["category3: 'Tính từ'"]
# --------------------
# Results for 'con quay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nóng sốt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trở thành': ["category2: 'Động từ'"]
# --------------------
# Results for 've vãn': ["category2: 'Động từ'"]
# --------------------
# Results for 'báo công': ["category2: 'Động từ'"]
# --------------------
# Results for 'tài danh': []
# --------------------
# Results for 'nuôi thả': ["category2: 'Động từ'"]
# --------------------
# Results for 'thăm nom': ["category2: 'Động từ'"]
# --------------------
# Results for 'ọp ẹp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nông nỗi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khảo cứu': ["category2: 'Động từ'"]
# --------------------
# Results for 'dao lam': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xét lại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rệu rã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'người rừng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đào mỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'báo tử': ["category2: 'Động từ'"]
# --------------------
# Results for 'tay vịn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cứ việc': []
# --------------------
# Results for 'quật cường': ["category2: 'Động từ'"]
# --------------------
# Results for 'thành thực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bồ bịch': ["category1: 'Danh từ'", "category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'quân sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đi giải': ["category2: 'Động từ'"]
# --------------------
# Results for 'chơi vơi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hải chiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'mao mạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chống chế': ["category2: 'Động từ'"]
# --------------------
# Results for 'oan nghiệt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khai sáng': ["category2: 'Động từ'"]
# --------------------
# Results for 'suy tôn': ["category2: 'Động từ'"]
# --------------------
# Results for 'bài vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'răng hàm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhún nhường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mất hồn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thứ bậc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'được việc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vùn vụt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cào cào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lớn khôn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ruột già': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngấp nghé': ["category2: 'Động từ'"]
# --------------------
# Results for 'kiên trung': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tranh tường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'càng cua': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cai sữa': ["category2: 'Động từ'"]
# --------------------
# Results for 'kính cẩn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bánh dẻo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thứ sử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngựa ô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'le lói': ["category2: 'Động từ'"]
# --------------------
# Results for 'chỏng chơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vanh vách': ["category3: 'Tính từ'"]
# --------------------
# Results for 'triệt sản': ["category2: 'Động từ'"]
# --------------------
# Results for 'thanh mai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đĩa cứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đức độ': []
# --------------------
# Results for 'với lại': []
# --------------------
# Results for 'bì bõm': ["category2: 'Động từ'"]
# --------------------
# Results for 'an lạc': []
# --------------------
# Results for 'nhảy cao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hình nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bần thần': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bạo chúa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bố dượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bên bị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đầu nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sám hối': ["category2: 'Động từ'"]
# --------------------
# Results for 'nội sinh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gói ghém': ["category2: 'Động từ'"]
# --------------------
# Results for 'sản giật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gán ghép': ["category2: 'Động từ'"]
# --------------------
# Results for 'lên dây': ["category2: 'Động từ'"]
# --------------------
# Results for 'to tướng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cua biển': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xuống tóc': ["category2: 'Động từ'"]
# --------------------
# Results for 'băng đạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chấm phá': ["category2: 'Động từ'"]
# --------------------
# Results for 'cá ngựa': ["category1: 'Danh từ'", "category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'cảng vụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sắc lạnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hướng ngoại': ["category2: 'Động từ'"]
# --------------------
# Results for 'thợ điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'răn dạy': ["category2: 'Động từ'"]
# --------------------
# Results for 'làm ơn': ["category2: 'Động từ'"]
# --------------------
# Results for 'địa hạt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đứng tuổi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiếu lâm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'náo động': ["category2: 'Động từ'"]
# --------------------
# Results for 'toàn năng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'y phục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thao thức': ["category2: 'Động từ'"]
# --------------------
# Results for 'o ép': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao xạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xám xịt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đại sự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đêm đêm': []
# --------------------
# Results for 'hàn huyên': ["category2: 'Động từ'"]
# --------------------
# Results for 'đầy tháng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lên cân': ["category2: 'Động từ'"]
# --------------------
# Results for 'xông pha': ["category2: 'Động từ'"]
# --------------------
# Results for 'rụng rời': ["category2: 'Động từ'"]
# --------------------
# Results for 'mưa tuyết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phủ tạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vương vấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'bánh răng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khoáng vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'máu mủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chợ lớn': []
# --------------------
# Results for 'đay nghiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'nằm lòng': []
# --------------------
# Results for 'ký sự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lạ đời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mỏng tang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chúc tụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà nguyện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cách điện': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'hội hè': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh binh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngược đời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kết tủa': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'bàn tính': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'thất hứa': ["category2: 'Động từ'"]
# --------------------
# Results for 'sức kéo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cô đọng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bông đùa': ["category2: 'Động từ'"]
# --------------------
# Results for 'bầu sô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tập tễnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiếp tân': ["category2: 'Động từ'"]
# --------------------
# Results for 'ân tr': []
# --------------------
# Results for 'mê muội': []
# --------------------
# Results for 'tiền trạm': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'ngư phủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ướt sũng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xương cốt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cung phụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'vườn tược': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trấn thủ': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thoá mạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đèn chùm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hồ nghi': ["category2: 'Động từ'"]
# --------------------
# Results for 'thơ ngây': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dựng chuyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'đung đưa': ["category2: 'Động từ'"]
# --------------------
# Results for 'thị thành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'học sinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hạ viện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhục hình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kết giao': ["category2: 'Động từ'"]
# --------------------
# Results for 'ký hoạ': []
# --------------------
# Results for 'bạo dạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'u buồn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bèo bọt': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'phóng túng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhân sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'văn sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bút bi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tưng tửng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngó ngàng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thương hàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vạ lây': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoang phế': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phong vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thú tội': ["category2: 'Động từ'"]
# --------------------
# Results for 'thù hằn': []
# --------------------
# Results for 'tiến thân': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhập nhằng': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'quần thảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'xuất trận': ["category2: 'Động từ'"]
# --------------------
# Results for 'cưỡng dâm': ["category2: 'Động từ'"]
# --------------------
# Results for 'phe cánh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khốn nạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dao bầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cực độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngưng tụ': ["category2: 'Động từ'"]
# --------------------
# Results for 'oi ả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lay chuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'xếp dỡ': ["category2: 'Động từ'"]
# --------------------
# Results for 'áp tải': ["category2: 'Động từ'"]
# --------------------
# Results for 'lãnh cảm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dâm bụt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'máy khoan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'buồn bực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nòi giống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'má mì': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hẹp hòi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xe đò': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vi hiến': []
# --------------------
# Results for 'khốn cùng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cất trữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'quá lời': []
# --------------------
# Results for 'tam quan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nguỵ tạo': ["category2: 'Động từ'"]
# --------------------
# Results for 'bắp đùi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuộc địa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'linh cẩu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hỏi vợ': ["category2: 'Động từ'"]
# --------------------
# Results for 'quang hợp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cà tàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chọc giận': ["category2: 'Động từ'"]
# --------------------
# Results for 'tâm tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hành hoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tăng viện': ["category2: 'Động từ'"]
# --------------------
# Results for 'thể th': []
# --------------------
# Results for 'phát kiến': []
# --------------------
# Results for 'ng thống': []
# --------------------
# Results for 'nội ô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cộng sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'truyền kiếp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tống khứ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tù đày': ["category2: 'Động từ'"]
# --------------------
# Results for 'phần phụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sình lầy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ho khan': ["category2: 'Động từ'"]
# --------------------
# Results for 'căng tin': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khiếp đảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'phái viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhũ đá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trơ trẽn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngoại lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'luỹ tiến': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngay thẳng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bản ngã': ["category1: 'Danh từ'"]
# --------------------
# Results for 'học sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao duyên': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'trợ giảng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dạn dĩ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'huynh đệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tủi hổ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'địch thủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cầm tinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'lúi húi': []
# --------------------
# Results for 'kêu gào': ["category2: 'Động từ'"]
# --------------------
# Results for 'miễn trách': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuyến yên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lô tô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tỳ vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vơ vét': ["category2: 'Động từ'"]
# --------------------
# Results for 'tương hỗ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khói hương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ma chay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đi rửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'biết nghĩ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cười trừ': ["category2: 'Động từ'"]
# --------------------
# Results for 'phòng ốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tĩnh điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tả tơi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đơn từ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sa thạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lá lách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giấy thấm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bài bạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khoai mì': ["category1: 'Danh từ'"]
# --------------------
# Results for 'người nhái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghiện hút': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghiêm nghị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dân công': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rầm rập': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thông hiểu': ["category2: 'Động từ'"]
# --------------------
# Results for 'trù bị': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'bán nguyệt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'triều chính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phơi phới': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thèm thuồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'rốt cục': []
# --------------------
# Results for 'số từ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trọng bệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lãnh đủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cơ quan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sán lá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công trạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dầu nhờn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hội đoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đĩnh đạc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bội thực': ["category2: 'Động từ'"]
# --------------------
# Results for 'va li': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tước vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lên khung': []
# --------------------
# Results for 'trước t': []
# --------------------
# Results for 'thành bộ': []
# --------------------
# Results for 'ca thán': ["category2: 'Động từ'"]
# --------------------
# Results for 'lâm bồn': ["category2: 'Động từ'"]
# --------------------
# Results for 'phì nhiêu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tứ giác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'băng chuyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cày xới': []
# --------------------
# Results for 'gái điếm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nặng nợ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'làm xiếc': []
# --------------------
# Results for 'đùa cợt': ["category2: 'Động từ'"]
# --------------------
# Results for 'kì dị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cát vàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đa cảm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dễ bề': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bồi lắng': ["category2: 'Động từ'"]
# --------------------
# Results for 'ấp úng': ["category2: 'Động từ'"]
# --------------------
# Results for 'giang sơn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ganh tị': []
# --------------------
# Results for 'ính phòng': []
# --------------------
# Results for 'văn tự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'va vấp': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thành văn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nghiêm trang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hiền dịu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'e sợ': ["category2: 'Động từ'"]
# --------------------
# Results for 'chấn hưng': ["category2: 'Động từ'"]
# --------------------
# Results for 'mời mọc': ["category2: 'Động từ'"]
# --------------------
# Results for 'rất mực': []
# --------------------
# Results for 'nhặt nhạnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'bẻ lái': ["category2: 'Động từ'"]
# --------------------
# Results for 'trách mắng': ["category2: 'Động từ'"]
# --------------------
# Results for 'ú ớ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nồi hơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rình rang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phèn chua': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mặc niệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'bưu thiếp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phập phồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bộ óc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hồng xiêm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'câm lặng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chạm ngõ': ["category2: 'Động từ'"]
# --------------------
# Results for 'quần âu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hầm hập': ["category3: 'Tính từ'"]
# --------------------
# Results for 'non nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chân chim': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thầy mo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiểu phẫu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tắm gội': ["category2: 'Động từ'"]
# --------------------
# Results for 'gia quyến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiên thời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lắng dịu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhãn khoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cho biết': []
# --------------------
# Results for 'bán công': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhục mạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cuốc bộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'bông gòn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tấm lợp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh mơ': []
# --------------------
# Results for 'bằng hữu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đỏ lửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'băng video': ["category1: 'Danh từ'"]
# --------------------
# Results for 'anh nuôi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sao nhãng': ["category2: 'Động từ'"]
# --------------------
# Results for 'hổ danh': ["category2: 'Động từ'"]
# --------------------
# Results for 'bắp chuối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gỡ gạc': ["category2: 'Động từ'"]
# --------------------
# Results for 'bo mạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tên riêng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cát cứ': ["category2: 'Động từ'"]
# --------------------
# Results for 'luống cuống': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuỷ quân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tròn trĩnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thân ái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rên rỉ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đường quan': []
# --------------------
# Results for 'nông cụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bè phái': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'bướu cổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mạt sát': ["category2: 'Động từ'"]
# --------------------
# Results for 'vật chủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dép lê': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lầm lỗi': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'trắng ngà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xen canh': ["category2: 'Động từ'"]
# --------------------
# Results for 'ni cô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chăn dắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'tưởng thưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'sơn nữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cả gan': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chân tướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biện chứng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trời ơi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giả như': []
# --------------------
# Results for 'già trẻ': []
# --------------------
# Results for 'bạc bẽo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khoảng không': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dẫn lưu': ["category2: 'Động từ'"]
# --------------------
# Results for 'gánh hát': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xin xỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'xanh đỏ': []
# --------------------
# Results for 'màng nhĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hình nộm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nh trùng': []
# --------------------
# Results for 'khoai sọ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhăm nhe': ["category2: 'Động từ'"]
# --------------------
# Results for 'chế độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dân biểu': []
# --------------------
# Results for 'hậu phẫu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dạng thức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dõng dạc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tào phớ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lò cao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chát chúa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giấy dó': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chứa chấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'chờ mong': ["category2: 'Động từ'"]
# --------------------
# Results for 'trấn lột': ["category2: 'Động từ'"]
# --------------------
# Results for 'cối xay': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'chấm hết': ["category2: 'Động từ'"]
# --------------------
# Results for 'bất giác': []
# --------------------
# Results for 'vôi bột': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mới rồi': []
# --------------------
# Results for 'hít hà': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoán cải': []
# --------------------
# Results for 'kim tiền': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'trao gửi': ["category2: 'Động từ'"]
# --------------------
# Results for 'tứ tung': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bố già': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dưỡng thai': ["category2: 'Động từ'"]
# --------------------
# Results for 'so đo': ["category2: 'Động từ'"]
# --------------------
# Results for 'bí truyền': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bệnh xá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuyến tài': ["category2: 'Động từ'"]
# --------------------
# Results for 'thu lượm': ["category2: 'Động từ'"]
# --------------------
# Results for 'lâm viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm gì': []
# --------------------
# Results for 'vô biên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mừng vui': []
# --------------------
# Results for 'phồn thịnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'an thai': ["category2: 'Động từ'"]
# --------------------
# Results for 'tính dục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'truy phong': ["category2: 'Động từ'"]
# --------------------
# Results for 'mắng nhiếc': ["category2: 'Động từ'"]
# --------------------
# Results for 'tạp kỹ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bà đỡ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thanh thế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rối rít': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dự liệu': ["category2: 'Động từ'"]
# --------------------
# Results for 'đại số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dịch hại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chu kì': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thánh thần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tư chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cửa cuốn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phường xã': []
# --------------------
# Results for 'đạp đổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà rông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thể hoá': []
# --------------------
# ...
# Results for 'biệt tích': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ba khía': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tống giam': ["category2: 'Động từ'"]
# --------------------
# Results for 'trông mong': ["category2: 'Động từ'"]
# --------------------
# Results for 'gió lùa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rửa tội': ["category2: 'Động từ'"]
# --------------------
# Results for 'hồng thuỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nấm men': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sai khiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'mát mắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'con bệnh': []
# --------------------
# Results for 'vời vợi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'răng nanh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuổi đầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'anh chức': []
# --------------------
# Results for 'hắc ám': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngả lưng': ["category2: 'Động từ'"]
# --------------------
# Results for 'pha trò': ["category2: 'Động từ'"]
# --------------------
# Results for 'uốn dẻo': ["category2: 'Động từ'"]
# --------------------
# Results for 'răng cửa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bọc lót': ["category2: 'Động từ'"]
# --------------------
# Results for 'giấy ăn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhí nhố': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cuồng tín': ["category2: 'Động từ'"]
# --------------------
# Results for 'lửa trại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xộc xệch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hải lưu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hờn dỗi': ["category2: 'Động từ'"]
# --------------------
# Results for 'loăng quăng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhuyễn thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bình định': ["category2: 'Động từ'"]
# --------------------
# Results for 'chỉ trỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'mãnh thú': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tạp vụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh động': ["category2: 'Động từ'"]
# --------------------
# Results for 'cắt cơn': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhân hoà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bạc mệnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thế tục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đưa mắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'tu luyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'lồng lộng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nóng ruột': ["category3: 'Tính từ'"]
# --------------------
# Results for 'già cả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sáo rỗng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ba kích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tốt tươi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bến bờ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhảy xa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'li khai': ["category2: 'Động từ'"]
# --------------------
# Results for 'ái tử': []
# --------------------
# Results for 'mang tai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bầu dục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bình thuỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phụ tình': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhập nhèm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cải táng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tinh giảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'đá cuội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lâm phần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lừa bịp': ["category2: 'Động từ'"]
# --------------------
# Results for 'tín hữu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lụt lội': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'hợp lưu': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tự tiện': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quyền thế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sát khí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rung rinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'vạ miệng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoen ố': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quân trang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'họp hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'đeo đẳng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà rường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hết ý': []
# --------------------
# Results for 'phóng điện': ["category2: 'Động từ'"]
# --------------------
# Results for 'bấm bụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tử thủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'giá thú': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuyền rồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhiệt kế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cần trục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'liêu xiêu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiền phương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'danh vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rọ mõm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'a trời': []
# --------------------
# Results for 'chi li': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đề xướng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bột nở': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hỗn láo': []
# --------------------
# Results for 'như điên': []
# --------------------
# Results for 'ở rể': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồng môn': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'căn chỉnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'vững tâm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dăm bảy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cực quyền': []
# --------------------
# Results for 'ái mộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ượng học': []
# --------------------
# Results for 'chìm xuồng': []
# --------------------
# Results for 'đầu bò': []
# --------------------
# Results for 'ong chúa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cường điệu': ["category2: 'Động từ'"]
# --------------------
# Results for 'đánh úp': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiết diện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tổng th': []
# --------------------
# Results for 'hiền tài': []
# --------------------
# Results for 'vĩ cầm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kilômét vuông': []
# --------------------
# Results for 'đầu bài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đài bay': []
# --------------------
# Results for 'tỉnh bơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tròn xoe': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngạo nghễ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'truyền tụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chả giò': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nguyên âm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đong đưa': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'đau yếu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tin mừng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lọ mọ': []
# --------------------
# Results for 'thao diễn': ["category2: 'Động từ'"]
# --------------------
# Results for 'bồ hòn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại hoá': []
# --------------------
# Results for 'phân lập': ["category2: 'Động từ'"]
# --------------------
# Results for 'sinh từ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiêu huỷ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ba lê': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thư tịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'văn hào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chợ trời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chải chuốt': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tâm tưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tàu lửa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'báo đáp': ["category2: 'Động từ'"]
# --------------------
# Results for 'canh phòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tàu lặn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sứ quân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quá trời': []
# --------------------
# Results for 'hạ giới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trò hề': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuếch trương': ["category2: 'Động từ'"]
# --------------------
# Results for 'du hí': []
# --------------------
# Results for 'thú thực': ["category2: 'Động từ'"]
# --------------------
# Results for 'lễ nghĩa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bờ rào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giải oan': ["category2: 'Động từ'"]
# --------------------
# Results for 'cười duyên': ["category2: 'Động từ'"]
# --------------------
# Results for 'để tang': ["category2: 'Động từ'"]
# --------------------
# Results for 'sơ đẳng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cấm chỉ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồ hộp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'viêm não': []
# --------------------
# Results for 'chong chóng': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tóc tai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quả báo': []
# --------------------
# Results for 'sa chân': ["category2: 'Động từ'"]
# --------------------
# Results for 'trào phúng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'học khoá': []
# --------------------
# Results for 'cầu cống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cắn xé': ["category2: 'Động từ'"]
# --------------------
# Results for 'chức vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ác nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chính thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xe bò': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bá quyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thoáng khí': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ăn khớp': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'í ới': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thâm thuý': ["category3: 'Tính từ'"]
# --------------------
# Results for 'man mác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đánh trống': []
# --------------------
# Results for 'thần kì': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tối om': ["category3: 'Tính từ'"]
# --------------------
# Results for 'huýt sáo': ["category2: 'Động từ'"]
# --------------------
# Results for 'lẽ nào': []
# --------------------
# Results for 'acid amin': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lập thân': ["category2: 'Động từ'"]
# --------------------
# Results for 'hồ điệp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngờ nghệch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vựa lúa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chọc trời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sắc phục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tứ xứ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'âm điệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cứng cỏi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'âu thuyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phóng thanh': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuỷ tiên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trác táng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thắng thầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'nông cạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuỷ cung': ["category1: 'Danh từ'"]
# --------------------
# Results for 'độc diễn': ["category2: 'Động từ'"]
# --------------------
# Results for 'chân như': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thánh giá': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'đãng trí': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghĩa hiệp': ["category3: 'Tính từ'"]
# --------------------
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[5], line 39
#      36 word = vocab_data[str(index)]
#      38 # Lấy lại các phần tử input và button trước mỗi lần tìm kiếm
# ---> 39 input_search = browser.find_element(By.ID, 'search')
#      40 search_button = browser.find_element(By.ID, 'btnSearch')
#      42 # Clear the input field
#
# File h:\AnacondaApp\envs\tf\lib\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File h:\AnacondaApp\envs\tf\lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File h:\AnacondaApp\envs\tf\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=126.0.6478.127)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF651F6EEB2+31554]
# 	(No symbol) [0x00007FF651EE7EE9]
# 	(No symbol) [0x00007FF651DA872A]
# 	(No symbol) [0x00007FF651D7D995]
# 	(No symbol) [0x00007FF651E244D7]
# 	(No symbol) [0x00007FF651E3C051]
# 	(No symbol) [0x00007FF651E1CDD3]
# 	(No symbol) [0x00007FF651DEA33B]
# 	(No symbol) [0x00007FF651DEAED1]
# 	GetHandleVerifier [0x00007FF652278B2D+3217341]
# 	GetHandleVerifier [0x00007FF6522C5AF3+3532675]
# 	GetHandleVerifier [0x00007FF6522BB0F0+3489152]
# 	GetHandleVerifier [0x00007FF65201E786+750614]
# 	(No symbol) [0x00007FF651EF376F]
# 	(No symbol) [0x00007FF651EEEB24]
# 	(No symbol) [0x00007FF651EEECB2]
# 	(No symbol) [0x00007FF651EDE17F]
# 	BaseThreadInitThunk [0x00007FFF5CB77344+20]
# 	RtlUserThreadStart [0x00007FFF5E2FCC91+33]
